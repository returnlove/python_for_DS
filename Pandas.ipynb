# %%
import pandas as pd

# %%
dataset = pd.read_csv("diabetes.csv")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
dataset.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
dataset.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
dataset[dataset["Glucose"] == 0].shape
# Out:
# (5, 9)

# %%
dataset.loc[dataset["Glucose"] == 0, ["Glucose"]] = None

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     763 non-null float64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(3), int64(6)
# memory usage: 54.1 KB

# %%
dataset.loc[dataset["BloodPressure"] == 0, ["BloodPressure"]] = None

# %%
dataset.loc[dataset["SkinThickness"] == 0, ["SkinThickness"]] = None

# %%
dataset.loc[dataset["Insulin"] == 0, ["Insulin"]] = None

# %%
dataset.loc[dataset["BMI"] == 0, ["BMI"]] = None

# %%
dataset.loc[dataset["DiabetesPedigreeFunction"] == 0, ["DiabetesPedigreeFunction"]] = None

# %%
dataset.loc[dataset["Age"] == 0, ["Age"]] = None

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     763 non-null float64
# BloodPressure               733 non-null float64
# SkinThickness               541 non-null float64
# Insulin                     394 non-null float64
# BMI                         757 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null float64
# Outcome                     768 non-null int64
# dtypes: float64(7), int64(2)
# memory usage: 54.1 KB

# %%
dataset.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  763.000000     733.000000     541.000000  394.000000
# mean      3.845052  121.686763      72.405184      29.153420  155.548223
# std       3.369578   30.535641      12.382158      10.476982  118.775855
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.000000      64.000000      22.000000   76.250000
# 50%       3.000000  117.000000      72.000000      29.000000  125.000000
# 75%       6.000000  141.000000      80.000000      36.000000  190.000000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  757.000000                768.000000  768.000000  768.000000
# mean    32.457464                  0.471876   33.240885    0.348958
# std      6.924988                  0.331329   11.760232    0.476951
# ...

# %%
dataset.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.128135       0.214178       0.100239
# Glucose                      0.128135  1.000000       0.223192       0.228043
# BloodPressure                0.214178  0.223192       1.000000       0.226839
# SkinThickness                0.100239  0.228043       0.226839       1.000000
# Insulin                      0.082171  0.581186       0.098272       0.184888
# BMI                          0.021719  0.232771       0.289230       0.648214
# DiabetesPedigreeFunction    -0.033523  0.137246      -0.002805       0.115016
# Age                          0.544341  0.267136       0.330107       0.166816
# Outcome                      0.221898  0.494650       0.170589       0.259491
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies               0.082171  0.021719                 -0.033523
# ...

# %%
dataset.corr() > 0.5
# Out:
#                           Pregnancies  Glucose  BloodPressure  SkinThickness  \
# Pregnancies                      True    False          False          False
# Glucose                         False     True          False          False
# BloodPressure                   False    False           True          False
# SkinThickness                   False    False          False           True
# Insulin                         False     True          False          False
# BMI                             False    False          False           True
# DiabetesPedigreeFunction        False    False          False          False
# Age                              True    False          False          False
# Outcome                         False    False          False          False
#
#                           Insulin    BMI  DiabetesPedigreeFunction    Age  \
# Pregnancies                 False  False                     False   True
# ...

# %%
dataset_norm = dataset - dataset.mean() / dataset.max() - dataset.min()

# %%
dataset_norm
# Out:
#      Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# 0        5.77382  103.388509      47.406515      27.705521         NaN
# 1        0.77382   40.388509      41.406515      21.705521         NaN
# 2        7.77382  138.388509      39.406515            NaN         NaN
# 3        0.77382   44.388509      41.406515      15.705521   79.816137
# 4       -0.22618   92.388509      15.406515      27.705521  153.816137
# 5        4.77382   71.388509      49.406515            NaN         NaN
# 6        2.77382   33.388509      25.406515      24.705521   73.816137
# 7        9.77382   70.388509            NaN            NaN         NaN
# 8        1.77382  152.388509      45.406515      37.705521  528.816137
# 9        7.77382   80.388509      71.406515            NaN         NaN
# 10       3.77382   65.388509      67.406515            NaN         NaN
# 11       9.77382  123.388509      49.406515            NaN         NaN
# ...

# %%
normalized = (dataset - dataset.mean()) / dataset.std()

# %%
normalized
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.639530  0.861722      -0.032723       0.558040       NaN  0.164987
# 1      -0.844335 -1.201441      -0.517291      -0.014643       NaN -0.845845
# 2       1.233077  2.007924      -0.678814            NaN       NaN -1.322380
# 3      -0.844335 -1.070446      -0.517291      -0.587327 -0.518188 -0.629238
# 4      -1.141108  0.501487      -2.617087       0.558040  0.104834  1.536831
# 5       0.342757 -0.186234       0.128800            NaN       NaN -0.990249
# 6      -0.250789 -1.430681      -1.809473       0.271699 -0.568703 -0.210464
# 7       1.826623 -0.218982            NaN            NaN       NaN  0.410475
# 8      -0.547562  2.466404      -0.194246       1.512514  3.262042 -0.282667
# 9       1.233077  0.108504       1.905550            NaN       NaN       NaN
# 10      0.045984 -0.382725       1.582504            NaN       NaN  0.742606
# ...

# %%
normalized["Outcome"] = (normalized["Outcome"] > 0.0)

# %%
normalized
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.639530  0.861722      -0.032723       0.558040       NaN  0.164987
# 1      -0.844335 -1.201441      -0.517291      -0.014643       NaN -0.845845
# 2       1.233077  2.007924      -0.678814            NaN       NaN -1.322380
# 3      -0.844335 -1.070446      -0.517291      -0.587327 -0.518188 -0.629238
# 4      -1.141108  0.501487      -2.617087       0.558040  0.104834  1.536831
# 5       0.342757 -0.186234       0.128800            NaN       NaN -0.990249
# 6      -0.250789 -1.430681      -1.809473       0.271699 -0.568703 -0.210464
# 7       1.826623 -0.218982            NaN            NaN       NaN  0.410475
# 8      -0.547562  2.466404      -0.194246       1.512514  3.262042 -0.282667
# 9       1.233077  0.108504       1.905550            NaN       NaN       NaN
# 10      0.045984 -0.382725       1.582504            NaN       NaN  0.742606
# ...

# %%
normalized.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null float64
# Glucose                     763 non-null float64
# BloodPressure               733 non-null float64
# SkinThickness               541 non-null float64
# Insulin                     394 non-null float64
# BMI                         757 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null float64
# Outcome                     768 non-null bool
# dtypes: bool(1), float64(8)
# memory usage: 48.8 KB
